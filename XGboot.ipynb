# %%
import pandas as pd
from sklearn.model_selection import train_test_split

from xgboost import XGBClassifier

# %%
# Load dataset
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv"
data = pd.read_csv(url, delimiter=";")

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
X = data.drop('quality', axis=1)

y = data['quality']

type(X)
print(y.head)
# Out:
# <bound method NDFrame.head of 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64>

# %%
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (1279, 11)
# (1279,)
# (320, 11)
# (320,)

# %%
# Define the model
model = XGBClassifier()

# Fit the model
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 5
#       2 model = XGBClassifier()
#       4 # Fit the model
# ----> 5 model.fit(X_train, y_train)
#
# File ~/.local/lib/python3.11/site-packages/xgboost/core.py:730, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     728 for k, arg in zip(sig.parameters, args):
#     729     kwargs[k] = arg
# --> 730 return func(**kwargs)
#
# File ~/.local/lib/python3.11/site-packages/xgboost/sklearn.py:1471, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1466     expected_classes = self.classes_
#    1467 if (
#    1468     classes.shape != expected_classes.shape
#    1469     or not (classes == expected_classes).all()
#    1470 ):
# -> 1471     raise ValueError(
#    1472         f"Invalid classes inferred from unique values of `y`.  "
#    1473         f"Expected: {expected_classes}, got {classes}"
#    1474     )
#    1476 params = self.get_xgb_params()
#    1478 if callable(self.objective):
#
# ValueError: Invalid classes inferred from unique values of `y`.  Expected: [0 1 2 3 4 5], got [3 4 5 6 7 8]

# %%
# Saving XGBoost Models

model.save_model('xgb_model.json')
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[13], line 3
#       1 # Saving XGBoost Models
# ----> 3 model.save_model('xgb_model.json')
#
# File ~/.local/lib/python3.11/site-packages/xgboost/sklearn.py:822, in XGBModel.save_model(self, fname)
#     820 meta["_estimator_type"] = self._get_type()
#     821 meta_str = json.dumps(meta)
# --> 822 self.get_booster().set_attr(scikit_learn=meta_str)
#     823 self.get_booster().save_model(fname)
#     824 self.get_booster().set_attr(scikit_learn=None)
#
# File ~/.local/lib/python3.11/site-packages/xgboost/sklearn.py:725, in XGBModel.get_booster(self)
#     722 if not self.__sklearn_is_fitted__():
#     723     from sklearn.exceptions import NotFittedError
# --> 725     raise NotFittedError("need to call fit or load_model beforehand")
#     726 return self._Booster
#
# NotFittedError: need to call fit or load_model beforehand
